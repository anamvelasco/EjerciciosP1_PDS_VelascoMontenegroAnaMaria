# %% [markdown]
# ### Ejercicios Clase 7

# %% [markdown]
# #### 1. Importe el archivo ztrans.py

# %%
from ztrans import *
import numpy as np # libreria básica operadores matemáticos y de arreglos
import matplotlib.pylab as plt # librería de graficación
from scipy.signal import tf2zpk
#%matplotlib inline

# %% [markdown]
# #### 2. Defina el numerador = [-0.2, 0, 0, 20, 0] y el denominador= [1, 2, 0, 15] . Encuentre los polos y los ceros de esta función. ¿Para que sirven los polos y los ceros?

# %%
num=[-0.2, 0, 0, 20, 0]
den=[1, 2, 0, 15]
print("Los polos de la función son: ",np.roots(den))
print("Los ceros de la función son: ",np.roots(num))
# Out:
# Los polos de la función son:  [-3.34255851+0.j          0.67127926+2.00921988j  0.67127926-2.00921988j]
# Los ceros de la función son:  [-2.32079442+4.01973384j -2.32079442-4.01973384j  4.64158883+0.j
#   0.        +0.j        ]

# %% [markdown]
# #### 3. Grafique la respuesta en frecuencia.

# %%
# %matplotlib inline
mfreqz(num,den)

# %% [markdown]
# #### 4. Grafique la respuesta al impulso y la respuesta al escalón. ¿Qué se puede analizar a partir de la gráfica?

# %%
# %matplotlib inline
impz(num,den)

# %% [markdown]
# #### 5. Realice el diagrama de polos y ceros

# %%
# %matplotlib inline
zeropoles(num,den)
